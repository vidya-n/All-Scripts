# %% [markdown]
# Optum case

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

count = 1
doctor_urls = []
web_suffix = 'https://www.optum.com/en/care'
options = webdriver.ChromeOptions()
driver =webdriver.Chrome('D:\Work\Forage AI\MC\minicrawl\configs\chromedriver-win64\chromedriver.exe', options= options)
while count <= 9:
    driver.get('https://www.optum.com/en/care/locations/colorado/optum-colorado/locations-nav/provider-lookup/provider-search-results.html?network=CONWP')
    time.sleep(3)

    doctors = driver.find_elements(By.XPATH, "//div[contains(@class, 'team__link')]")
    for doctor in doctors:
        url = web_suffix + doctor.get_attribute('data-route')
        doctor_urls.append(url)
    try:
        print(f"Page {count} done.", len(doctor_urls))
        driver.find_element(By.XPATH, '//button[contains(@aria-label, "Next page")]').click()
        time.sleep(3)
        count = count + 1
    except:
        print("Elementclick failed")
        break
    
print(len(doctor_urls))
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 9
#       7 web_suffix = 'https://www.optum.com/en/care'
#       8 options = webdriver.ChromeOptions()
# ----> 9 driver =webdriver.Chrome('D:\Work\Forage AI\MC\minicrawl\configs\chromedriver-win64\chromedriver.exe', options= options)
#      10 while count <= 9:
#      11     driver.get('https://www.optum.com/en/care/locations/colorado/optum-colorado/locations-nav/provider-lookup/provider-search-results.html?network=CONWP')
#
# TypeError: WebDriver.__init__() got multiple values for argument 'options'

# %%
import hashlib
import time

from custom_scripts.base_script import BaseScript
from selenium.webdriver.common.by import By


class Optum(BaseScript):
    @property
    # def __int__(self):
        # use create chrome driver only If needed
        # self.selenium_utils = SeleniumUtils(self.driver, self.logger)

    def process_data(self):
        profiles = []
        count = 1
        base_url = 'https://www.optum.com/en/care'
        url = 'https://www.optum.com/en/care/locations/colorado/optum-colorado/locations-nav/provider-lookup/provider-search-results.html?network=CONWP'
        print("hitting the url")
        self.driver.get(url)
        time.sleep(3)
        while True:
            print("test")
            page_count = count

            elements = self.driver.find_elements(By.XPATH, '//div[contains(@class, "team__link")]')
            if elements:
                print("data-extracted")
                for i in elements:
                    doc_url = base_url + i.get_attribute('data-route')
                    print("doctor url: ", doc_url)
                    hash_object = hashlib.sha256(str(doc_url).encode('utf-8'))
                    profile_id = hash_object.hexdigest()
                    obj1 = str(self.client_id) + profile_id + self.runs
                    # +str(page_count)
                    hex_dig1 = hashlib.sha256(str(obj1).encode('utf-8'))
                    # store = []
                    # print("Hash-check")
                    data_dict = {
                        'find_doctor_url': url,
                        'profile_link': doc_url,
                        'pages_count': page_count,
                        'dhc_id': str(self.client_id),
                        'domain_id': str(self.domain_id),
                        'domain_url': str(self.domain_url),
                        'profile_id': profile_id,
                        'text': "-",
                        'runs': self.runs,
                        'ajax': "-",
                        'extra': "-",
                        'json_data': "-",
                        'objectkey': hex_dig1.hexdigest()}
                    # store.append(doc_url)
                    # store.append(page_count)
                    # store.append(doc_name)
                    # print("CheckCheck1")
                    profiles.append(data_dict)
                    # yield store
                    print(len(profiles))
            try:
                print(f"Page {count} done.")
                self.driver.find_element(By.XPATH, '//button[contains(@aria-label, "Next page")]').click()
                time.sleep(3)
                count = count + 1
            except Exception as e:
                print("Element-click failed")
                #break
            if self.check_repeated_pages(profiles):
                break
            # else:
            #     break
            # return profiles

        return self.profiles

# %% [markdown]
# Wellstar case

# %%
import requests
from bs4 import BeautifulSoup as bs
import time
from lxml import html

url = 'https://www.wellstar.org/physicians?wellstar%2Bmedical%2Bgroup=1&v=1'
base_url = 'https://www.wellstar.org/physicians/'
r = requests.get(url)
print(r.status_code)
soup = bs(r.content, "html.parser")
tree = html.fromstring(r.content)
print(soup.prettify())
# Out:
# 200
# <!DOCTYPE html>
# <!--[if IE 9]><html lang="en" class="ie9 no-js"><![endif]-->
# <!--[if !IE]><!-->
# <html lang="en-US">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport">
#    <link href="//maps.googleapis.com" rel="preconnect dns-prefetch"/>
#    <link href="//apps10.erexpress.com" rel="preconnect dns-prefetch"/>
#    <link href="//www.googletagmanager.com" rel="preconnect dns-prefetch"/>
#    <link href="//players.brightcove.net" rel="preconnect dns-prefetch"/>
#    <link href="//vjs.zencdn.net" rel="preconnect dns-prefetch"/>
#    <link href="//metrics.brightcove.com" rel="preconnect dns-prefetch"/>
#    <link href="//edge.api.brightcove.com" rel="preconnect dns-prefetch"/>
#    <link href="//f1.media.brightcove.com" rel="preconnect dns-prefetch"/>
# ...

# %% [markdown]
# MoreHouseHealthcare case

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

driver =webdriver.Chrome('D:\Work\Forage AI\MC\minicrawl\configs\chromedriver-win64\chromedriver.exe')
url = 'https://www.morehousehealthcare.com/physicians/index.php'
driver.get(url)
count = 1
profiles = []

while count <= 6:
    page_count = count
    data = driver.find_elements(By.XPATH, "//td/h4/a")
    if data:
        for i in data:
            doc_url = i.get_attribute('href')
            print(doc_url)
            profiles.append(doc_url)  
    try:
        print(f"Page {page_count} done.")
        print(len(profiles))
        driver.find_element(By.XPATH, '//li[contains(@class, "paginate_button next")]/a').click()
        count = count + 1
    except Exception:
        print("element-click failed")
        break

print(len(profiles))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\nyaya\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\common\driver_finder.py:38, in DriverFinder.get_path(service, options)
#      37 try:
# ---> 38     path = SeleniumManager().driver_location(options) if path is None else path
#      39 except Exception as err:
#
# File c:\Users\nyaya\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\common\selenium_manager.py:71, in SeleniumManager.driver_location(self, options)
#      64 """
#      65 Determines the path of the correct driver.
#      66 :Args:
#      67  - browser: which browser to get the driver path for.
#      68 :Returns: The driver path to use
#      69 """
# ---> 71 browser = options.capabilities["browserName"]
#      73 args = [str(self.get_binary()), "--browser", browser]
#
# ...

# %%
import hashlib
import time

from custom_scripts.base_script import BaseScript
from selenium.webdriver.common.by import By


class Morehousehealthcare(BaseScript):
    @property
    # def __int__(self):
        # use create chrome driver only If needed
        # self.selenium_utils = SeleniumUtils(self.driver, self.logger)

    def process_data(self):
        profiles = []
        count = 1
        #base_url = 'https://www.morehousehealthcare.com/'
        url = 'https://www.morehousehealthcare.com/physicians/index.php'
        print("hitting the url")
        self.driver.get(url)
        time.sleep(3)
        while True:
            print("test")
            page_count = count

            elements = self.driver.find_elements(By.XPATH, "//td/h4/a")
            if elements:
                print("data-extracted")
                for i in elements:
                    doc_url = i.get_attribute('href')
                    print(doc_url)
                    hash_object = hashlib.sha256(str(doc_url).encode('utf-8'))
                    profile_id = hash_object.hexdigest()
                    obj1 = str(self.client_id) + profile_id + self.runs
                    # +str(page_count)
                    hex_dig1 = hashlib.sha256(str(obj1).encode('utf-8'))
                    # store = []
                    # print("Hash-check")
                    data_dict = {
                        'find_doctor_url': url,
                        'profile_link': doc_url,
                        'pages_count': page_count,
                        'dhc_id': str(self.client_id),
                        'domain_id': str(self.domain_id),
                        'domain_url': str(self.domain_url),
                        'profile_id': profile_id,
                        'text': "-",
                        'runs': self.runs,
                        'ajax': "-",
                        'extra': "-",
                        'json_data': "-",
                        'objectkey': hex_dig1.hexdigest()}
                    # store.append(doc_url)
                    # store.append(page_count)
                    # store.append(doc_name)
                    # print("CheckCheck1")
                    profiles.append(data_dict)
                    # yield store
                    print(len(profiles))
            try:
                print(f"Page {page_count} done.")
                self.driver.find_element(By.XPATH, '//li[contains(@class, "paginate_button next")]/a').click()
                time.sleep(3)
                count = count + 1
            except Exception as e:
                print("Element-click failed")
                #break
            if self.check_repeated_pages(profiles):
                break
            # else:
            #     break
            # return profiles

        return self.profiles

# %% [markdown]
# rmg.nm case

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time


url = 'https://www.nm.org/doctors/search-results?medicalgrouplist=nmg&medicalgrouplist=northwesternmedicineregionalmedicalgroup&sort=distance&page=1&pagesize=24'
driver =webdriver.Chrome()

driver.get(url)
time.sleep(10)
count = 1
profiles = []

while count <= 165:
    page_count = count
    data = driver.find_elements(By.XPATH, '//a[contains(@class, "doctor-name")]')
    if data:
        for i in data:
            doc_url = i['href']
            print(doc_url)
            profiles.append(doc_url)
    try:
        print(f"Page {page_count} done.")
        print(len(profiles))
        driver.find_element(By.XPATH, '//span[contains(@class, "button-next")]').click()
        time.sleep(3)
    except Exception:
        print("element-click failed")
        break
print(len(profiles))
driver.quit()
# Out:
# Page 1 done.
# 0
# element-click failed
# 0

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

url = 'https://rmg.nm.org/find-a-doctor/find-a-doctor-advanced?specialty=&location='
driver =webdriver.Chrome('D:\Work\Forage AI\MC\minicrawl\configs\chromedriver-win64\chromedriver.exe')

driver.get(url)
time.sleep(10)
data = driver.find_elements(By.XPATH, '//a[contains(@class, "doctor-name")]')
for i in data:
    doc_url = i['href']
    print(doc_url)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\nyaya\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\common\driver_finder.py:38, in DriverFinder.get_path(service, options)
#      37 try:
# ---> 38     path = SeleniumManager().driver_location(options) if path is None else path
#      39 except Exception as err:
#
# File c:\Users\nyaya\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\common\selenium_manager.py:71, in SeleniumManager.driver_location(self, options)
#      64 """
#      65 Determines the path of the correct driver.
#      66 :Args:
#      67  - browser: which browser to get the driver path for.
#      68 :Returns: The driver path to use
#      69 """
# ---> 71 browser = options.capabilities["browserName"]
#      73 args = [str(self.get_binary()), "--browser", browser]
#
# ...

# %%
import requests
from bs4 import BeautifulSoup
import time

url = 'https://rmg.nm.org/find-a-doctor/find-a-doctor-advanced?specialty=&location='
r = requests.get(url)
print(r.status_code)
# Out:
# 200

# %% [markdown]
# cls.health case

# %%
import requests
from bs4 import BeautifulSoup
import time

url = 'https://cls.health/providers/'
headers = {
            'Accept-Language': 'en-US,en;q=0.9',
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
            'method': 'GET',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
            'Cookie': 'pbid=5a13213dca19b353a11b744aef4db4fd82cd900693d301aa6f5915b5862864da; _ga=GA1.1.1521367184.1712567892; pys_start_session=true; last_pysTrafficSource=direct; last_pys_landing_page=https://cls.health/providers/; _fbp=fb.1.1712567893630.9478542134; _ga_S5YRLPREN4=GS1.1.1713230944.7.0.1713230944.0.0.0; pys_session_limit=true; pys_first_visit=true; pysTrafficSource=direct; pys_landing_page=https://cls.health/providers/; _clck=1nih4ai%7C2%7Cfkz%7C0%7C1559; _ga_V17Q0M2N9J=GS1.1.1713230945.7.0.1713230945.0.0.0; _clsk=m5dogs%7C1713230945893%7C1%7C1%7Ca.clarity.ms%2Fcollect'
}
r = requests.get(url)
print(r.content)
# Out:
# b'403 - Forbidden | Access to this page is forbidden.\n'

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time


url = 'https://cls.health/providers/'
driver =webdriver.Chrome()

driver.get(url)
time.sleep(5)
count = 1
profiles = []

while count <= 6:
    page_count = count
    data = driver.find_elements(By.XPATH, '//a[contains(@class, "view-profile")]')
    if data:
        for i in data:
            doc_url = i.get_attribute('href')
            print(doc_url)
            profiles.append(doc_url)
    try:
        print(f"Page {page_count} done.")
        print(len(profiles))
        driver.find_element(By.XPATH, '//a[contains(@class, "nextpostslink")]').click()
        time.sleep(5)
        count = count + 1
    except Exception:
        print("element-click failed")
        break
print(len(profiles))
driver.quit()
# Out:
# https://cls.health/providers/abdul-a-abdellatif-md-fasn/
# https://cls.health/providers/katafan-achkar/
# https://cls.health/providers/ahmad-omair-md/
# https://cls.health/providers/moustafa-ahmed/
# https://cls.health/providers/hadi-akhtar-md/
# https://cls.health/providers/anurag-albert/
# https://cls.health/providers/farrah-ali-np/
# https://cls.health/providers/aaliya-amer-md/
# https://cls.health/providers/madiha-ashraf-md/
# https://cls.health/providers/magdy-attia/
# https://cls.health/providers/wendy-abellar-np/
# https://cls.health/providers/nedal-adi-md/
# https://cls.health/providers/ahmad-zunair-md/
# https://cls.health/providers/ahmed-tanvir-md/
# https://cls.health/providers/maha-k-al-lahiq-md/
# https://cls.health/providers/omar-m-albustami-md/
# https://cls.health/providers/naureen-alim-md/
# https://cls.health/providers/isra-amer-md/
# https://cls.health/providers/emran-atherah-md/
# https://cls.health/providers/mohammad-j-baba-md-fccp/
# ...

# %%
import asyncio
from playwright.async_api import async_playwright

async def main():
    async with async_playwright() as p:
        # Launch a Chromium browser
        browser = await p.chromium.launch(headless=False)
        page = await browser.new_page()  # Create a new page instance

        url = 'https://cls.health/providers/'
        await page.goto(url)  # Navigate to the URL

        # Wait for 5 seconds
        await page.wait_for_timeout(5000)

        count = 1
        profiles = []

        while count <= 6:
            page_count = count
            # Find all elements matching the XPath
            data = await page.query_selector_all('//a[contains(@class, "view-profile")]')
            if data:
                for i in data:
                    doc_url = await i.get_attribute('href')
                    print(doc_url)
                    profiles.append(doc_url)
            try:
                print(f"Page {page_count} done.")
                print(len(profiles))
                # Click the next page link
                await page.click('a.nextpostslink')
                # Wait for 5 seconds
                await page.wait_for_timeout(5000)
                count = count + 1
            except Exception as e:
                print("element-click failed:", e)
                break

        print(len(profiles))
        await browser.close()  # Close the browser

# Run the main function
asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 44
#      41         await browser.close()  # Close the browser
#      43 # Run the main function
# ---> 44 asyncio.run(main())
#
# File c:\Users\nyaya\AppData\Local\Programs\Python\Python310\lib\asyncio\runners.py:33, in run(main, debug)
#       9 """Execute the coroutine and return the result.
#      10
#      11 This function runs the passed coroutine, taking care of
#    (...)
#      30     asyncio.run(main())
#      31 """
#      32 if events._get_running_loop() is not None:
# ---> 33     raise RuntimeError(
#      34         "asyncio.run() cannot be called from a running event loop")
#      36 if not coroutines.iscoroutine(main):
#      37     raise ValueError("a coroutine was expected, got {!r}".format(main))
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

driver = webdriver.Chrome('D:\Work\Forage AI\MC\minicrawl\configs\chromedriver-win64\chromedriver.exe')
url = 'https://cls.health/providers/'
driver.get(url)
time.sleep(3)
count = 1
profiles = []

while count <= 6:
    page_count = count
    
    

driver.quit()

# %% [markdown]
# TuftsMedicine.org

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

url = 'https://www.tuftsmedicine.org/find-a-doctor?yext_retrieveFacets=true&yext_sortBys=%5B%7B%22type%22%3A%22RELEVANCE%22%7D%5D&yext_input=Melrose+Wakefield+Hospital&yext_offset=0&yext_limit=16&yext_facetFilters=%7B%7D'

driver = webdriver.Chrome()
driver.get(url)
time.sleep(3)
doctor_urls = []
doctors = driver.find_elements(By.XPATH, 'div[contains(@class, "profile-link")]/a')
for doc in doctors:
    print(doc.get_attribute('href'))
driver.quit()

# %% [markdown]
# UMMS case

# %%
import requests
from bs4 import BeautifulSoup as bs
import time


url = 'https://www.umms.org/find-a-doctor?qtext=+&q=+&si=uch&dist=200&perpage=10page=1&sort=Alpha&st=FindADoctor#search'
r = requests.get(url)
print(r.status_code)
# Out:
# 403

# %% [markdown]
# NCH doctors

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time


url = 'https://nchdoctors.org/patients-and-visitors/find-a-doctor/'
driver = webdriver.Chrome()
driver.get(url)
time.sleep(5)
count = 1
profiles = []

while count <= 42:
    page_count = count
    elements = driver.find_elements(By.XPATH, '//a[contains(@class, "nch-profile-link")]')
    if elements:
        for i in elements:
            doc_url = i.get_attribute('href')
            print(doc_url)
            profiles.append(doc_url)
    try:
        print(f"Page {page_count} done.")
        print(len(profiles))
        driver.find_element(By.XPATH, '//a[contains(@class, "page-numbers next")]').click()
        time.sleep(3)
        count = count + 1
    except Exception:
        print("element-click failed")
        break
print(len(profiles))
driver.quit()
# Out:
# Page 1 done.
# 0
# element-click failed
# 0

# %%
# redirected search page - scroll type.

from selenium import webdriver
from selenium.webdriver.common.by import By
import time

url = 'https://nchmd.org/providers/'
driver = webdriver.Chrome()
driver.get(url)
time.sleep(5)
count = 1
profiles = []

while count <= 43:
    page_count = count
    elements = driver.find_elements(By.XPATH, '//a[contains(@class, "btn-secondary card-link")]')
    if elements:
        for i in elements:
            doc_url = i.get_attribute('href')
            print(doc_url)
            profiles.append(doc_url)
    """try:
        print(f"Page {page_count} done.")
        print(len(profiles))
        driver.find_element(By.XPATH, '//li[contains(@class, "page-number active")]/following-sibling::li[1]/a').click()
        time.sleep(3)
        count = count + 1
    except Exception:
        print("element-click failed")
        break"""
print(len(profiles))
driver.quit()

# %% [markdown]
# # MEDSTAR CASE

# %%
import requests
from bs4 import BeautifulSoup as bs
import time
from lxml import html

url = 'https://www.medstarhealth.org/doctors#doctorssearch_hospital%20affiliations=MedStar%20Washington%20Hospital%20Center&doctorssearch_g=39.4062154%7C-76.4505243&doctorssearch_distance%20by%20miles=25000&doctorssearch_o=Distance%2CAscending'
r = requests.get(url)
soup = bs(r.content, "html.parser")
tree= html.fromstring(r.content)

doctors = tree.xpath('//a[contains(., "view profile")]')
print(len(doctors))
# Out:
# 0

# %%
import requests
from bs4 import BeautifulSoup as bs
from lxml import html
import time

url = 'https://www.medstarhealth.org/doctors#doctorssearch_hospital%20affiliations=MedStar%20Washington%20Hospital%20Center&doctorssearch_g=39.4062154%7C-76.4505243&doctorssearch_distance%20by%20miles=25000&doctorssearch_o=Distance%2CAscending'

payload = {"1B710E23-8C3E-4D66-86FF-FE6EF431929F}&itemid={55B863AA-C8E0-44A4-97EB-B0F24E3AA986}&sig=doctorssearch&hospital%20affiliations=MedStar%20Washington%20Hospital%20Center&distance%20by%20miles=25000&g=39.4062154%7C-76.4505243&o=Distance%2CAscending&p=20&v=%7BBF0E19AC-D67C-48E8-B917-CB4542E82559%7D"}
headers = {
            'Accept-Language': 'en-US,en;q=0.9',
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
            'method': 'GET',
            'Accept': 'application/json, text/javascript, */*; q=0.01',
            'Cookie': '_gcl_au=1.1.1317536898.1710740910; bid_mhp8uu7sh1crf8011b0jpj4l2bwdpk1i=5617667f-a846-49c7-840b-562a3e5158a1; _CEFT=Q%3D%3D%3D; sxa_site=Medstar; AMCVS_D115064C655BC1590A495C89%40AdobeOrg=1; AMCV_D115064C655BC1590A495C89%40AdobeOrg=179643557%7CMCIDTS%7C19824%7CMCMID%7C51041508021708249462395679126591332056%7CMCAAMLH-1713318658%7C12%7CMCAAMB-1713318658%7C6G1ynYcLPuiQxYZrsz_pkqfLG9yMXBpb2zX5dvJdYQJzPXImdj0y%7CMCOPTOUT-1712721058s%7CNONE%7CMCSYNCSOP%7C411-19808%7CvVersion%7C5.5.0; sessionUniqueId=994198269b244f8597ab661b673d5ae6; _ce.irv=returning; cebs=1; bx_bucket_number=32; bx_guest_ref=43359471-0830-4699-a24e-893530446811; kndctr_D115064C655BC1590A495C89_AdobeOrg_identity=CiY1MTA0MTUwODAyMTcwODI0OTQ2MjM5NTY3OTEyNjU5MTMzMjA1NlIRCNzl6oDlMRgBKgRJTkQxMAPwAZHz-e3sMQ==; kndctr_D115064C655BC1590A495C89_AdobeOrg_cluster=ind1; _ce.clock_event=1; _ce.clock_data=1791%2C45.127.59.91%2C1%2C5e705226acd7a97aa6ee95ab188632d6; cebsp_=3; _ce.s=v~18b4027d89ab69ed81dbe0d962a7f9702736751b~lcw~1712850055341~lva~1712713865447~vpv~1~v11.cs~225675~v11.s~f77eb7f0-f816-11ee-90d7-6121737d7bab~v11.sla~1712850056569~gtrk.la~luvep2f3~v11.send~1712850055341~lcw~1712850056569'                
}
base_url = 'https://www.medstarhealth.org/'
r = requests.get(url)
soup = bs(r.content, "html.parser")
#print(soup.prettify)

load_more = soup.find()
# Out:
# <bound method Tag.prettify of
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en">
# <!--<![endif]-->
# <head>
# <link href="/-/media/base-themes/core-libraries/styles/optimized-min.css?t=20200528T161545Z" rel="stylesheet"/><link href="/-/media/base-themes/main-theme/styles/optimized-min.css?t=20200528T161546Z" rel="stylesheet"/><link href="/-/media/themes/mho/medstar/mho-theme/styles/optimized-min.css?t=20240326T125835Z" rel="stylesheet"/>
# <title>Find a Doctor | MedStar Health</title>
# <link href="https://www.medstarhealth.org/doctors" rel="canonical"/>
# <link href="/-/media/project/mho/medstar/icons/favicon.png" rel="shortcut icon"/>
# ...

# %% [markdown]
# # ochsnerlsuhs.org

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

i = 0
url = f'https://search.ochsnerlsuhs.org/doctors?p=doctors&limit=50&offset={i}'
driver = webdriver.Chrome()

profiles = []
while i <= 500:
    url = f'https://search.ochsnerlsuhs.org/doctors?p=doctors&limit=50&offset={i}'
    driver.get(url)
    time.sleep(10)
    doctors = driver.find_elements(By.XPATH, '//a[contains(@class, "items-center")]')
    for doc in doctors:
        doc_url = doc.get_attribute('href')
        profiles.append(doc_url)
    print(len(profiles))
    i = i + 50
driver.quit()
# Out:
# 49
# 99
# 149
# 199
# 248
# 296
# 345
# 393
# 443
# 493
# 498

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

i = 0
url = f'https://search.ochsnerlsuhs.org/doctors?p=doctors&limit=50&offset={i}'

# %% [markdown]
# # cls.health

# %%
import hashlib
import time
import requests
from bs4 import BeautifulSoup


class Clshealth:
    # def __int__(self):
    #     use create chrome driver only If needed
    #     self.selenium_utils = SeleniumUtils(self.driver, self.logger)

    def process_data(self):
        count = 1
        profiles = []
        

        while True:
            print("test")
            url = 'https://cls.health/providers/'
            print("hitting the url", url)
            page_count = count
            
            payload = {}
            headers = {
                user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'
            
            }
            
            soup = BeautifulSoup(response.content, 'html.parser')
            elements = soup.find_all('a', class_='view-profile')

            if elements:
                print("data-extracted")
                for i in elements:
                    doc_url = i['href']
                    print("doctor url: ", doc_url)
                    hash_object = hashlib.sha256(str(doc_url).encode('utf-8'))
                    profile_id = hash_object.hexdigest()
                    obj1 = str(self.client_id) + profile_id + self.runs
                    hex_dig1 = hashlib.sha256(str(obj1).encode('utf-8'))
                    data_dict = {
                        'find_doctor_url': url,
                        'profile_link': doc_url,
                        'pages_count': page_count,
                        'dhc_id': str(self.client_id),
                        'domain_id': str(self.domain_id),
                        'domain_url': str(self.domain_url),
                        'profile_id': profile_id,
                        'text': "-",
                        'runs': self.runs,
                        'ajax': "-",
                        'extra': "-",
                        'json_data': "-",
                        'objectkey': hex_dig1.hexdigest()}
                    self.profiles.append(data_dict)
                    print(len(self.profiles))

            try:
                print(f"Page {count} done.")
                next_page_link = soup.find('a', class_='nextpostslink')['href']
                response = requests.get(next_page_link)
                time.sleep(3)
                count += 1
            except Exception as e:
                print("Element-click failed")
                break

            if self.check_repeated_pages(self.profiles):
                break

        return self.profiles

# %% [markdown]
# # Crouse.org

# %%
import requests
from bs4 import BeautifulSoup as bs
import time

url = 'https://www2.crouse.org/doctor/i_results.asp'
payload = {
    'selPhysician': 
    'rbtnGender': 'NA'
    'selSpecialty': 
    'selPractice': 
    'selCity': 
    'btnSubmit': 'Find+A+Doctor+%3E'
}
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36'
}
r = requests.get(url)

# %% [markdown]
# # Brownmed.org
