# %% [markdown]
# # Carle.org

# %%
import requests

url = 'https://fap-feed.carle.com/Provider/search?name=&tag=&location=Carle%20Richland%20Memorial%20Hospital&radius=10&lat=&lng='

base_url = 'https://carle.org/find-a-doctor/'
headers = {
    'Accept': '*/*',
    'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://carle.org/',
    'Sec-Cha-Ua': '"Chromium";v="128", "Not;A=Brand";v="24", "Google Chrome";v="128"',
    'Sec-Cha-Ua-Mobile': '?0',
    'Sec-Cha-Ua-Platform': '"Windows"',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36'
}

r = requests.get(url, headers=headers)
doc_urls = []
for i in r.json():
    print(i['Id'])
    doc_urls.append(base_url + str(i['Id'])) 
    print(base_url + str(i['Id']))   

print("Total docs: ", len(doc_urls))

# %% [markdown]
# # City of Hope

# %%
import requests
from bs4 import BeautifulSoup as bs

url = 'https://www.cityofhope.org/patients/find-a-doctor?page=0'
base = 'https://www.cityofhope.org'

page = 0
headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Accept-Language': 'en-US,en;q=0.9',
    'Cache-Control': 'max-age=0',
    'Cookie': '__cf_bm=qSaOckWks0nbovDEavEXxUXnIWmr_9bTXl3teVerj3o-1727263909-1.0.1.1-.Fv_TlmvmBBiN435OaBrGO7QhFhggsjuIShek_feP3tmfvww9H3W3aHPi9rKK_cvpkqgEPyh54DFOEIQt7x21w; _gcl_au=1.1.239578492.1727263910; _ga=GA1.1.2072042580.1727263911; cf_clearance=RKQwREI8f6EXA6mLizmnj02zMfCqgU4PIV9n7DoeKxU-1727263912-1.2.1.1-W3ukPoL1_g2B0xSTQsaDaJOZbEsn71x4wjqTeuGuO3.MSx_jwDZWcrvsCvFr.UckXu_uaCO3JAjcc5HIqNlv4O_fi9UokO4u81kWHnyjy1UrzYi0Yo7um7xDx4B7Z7RILSBKQ48BfNH6qJTeKg908ElI1tOTNQEPoshYtuhy02CUvjFJ2qu6ChMc5aZOtZOKBojTvX.O29w_PdOd2jM1Bat3dtB0LkkzmP3awIPFyTz9v4E_95BM3S6cjwmuqFjW9RPRivSqSoihzEbAu2cyPpBgjFq8gI0QJBOKHMhe1TwF_jcAw7mvxlFf4UPuA8qK_Tl8CKwSU1nltubdr2C8lgiDALsOkWXRYbaKMG8SgAS8kAB1pmcUDoO9_RnZpTkz; _ga_K625FN3PRT=GS1.1.1727263911.1.0.1727263911.0.0.0; invoca_session=%7B%22ttl%22%3A%222024-09-26T11%3A33%3A50.917Z%22%2C%22session%22%3A%7B%22abtasty_vid%22%3A%22na%22%2C%22campaign%22%3A%22unknown%22%2C%22content%22%3A%22non_branded%22%2C%22current_page%22%3A%22https%3A%2F%2Fwww.cityofhope.org%2Fpatients%2Ffind-a-doctor%22%2C%22current_path%22%3A%22%2Fpatients%2Ffind-a-doctor%22%2C%22dc_id%22%3A%22na%22%2C%22entry_page%22%3A%22https%3A%2F%2Fwww.cityofhope.org%2Fpatients%2Ffind-a-doctor%22%2C%22gclid%22%3A%22na%22%2C%22host%22%3A%22www.cityofhope.org%22%2C%22medium%22%3A%22organic%22%2C%22referrer%22%3A%22https%3A%2F%2Fwww.google.com%2F%22%2C%22referring_domain%22%3A%22www.google.com%22%2C%22session_campaign%22%3A%7B%22sourcecode%22%3A%22non_branded_natural_search_google%22%2C%22invsrc%22%3A%22na%22%2C%22utm_source%22%3A%22na%22%2C%22utm_medium%22%3A%22na%22%2C%22utm_campaign%22%3A%22na%22%2C%22utm_content%22%3A%22na%22%2C%22utm_term%22%3A%22na%22%2C%22t_pur%22%3A%22na%22%2C%22t_si%22%3A%22na%22%2C%22t_plc%22%3A%22na%22%2C%22t_sz%22%3A%22na%22%2C%22t_con%22%3A%22na%22%2C%22t_ctv%22%3A%22na%22%2C%22t_src%22%3A%22na%22%2C%22t_cam%22%3A%22na%22%2C%22t_adg%22%3A%22na%22%2C%22t_trm%22%3A%22na%22%2C%22t_mtp%22%3A%22na%22%2C%22t_pos%22%3A%22na%22%2C%22t_mdm%22%3A%22na%22%2C%22t_crt%22%3A%22na%22%7D%2C%22site_activities%22%3A%7B%22session_counter%22%3A1%2C%22session_pages_seen%22%3A1%2C%22total_pages_seen%22%3A1%2C%22first_session_start_time%22%3A%222024-09-25T11%3A31%3A50.474Z%22%2C%22session_start_time%22%3A%222024-09-25T11%3A31%3A50.474Z%22%2C%22visitor_type%22%3A%22new%22%2C%22session_current_time%22%3A%222024-09-25T11%3A31%3A50.474Z%22%2C%22session_duration%22%3A0%2C%22recency%22%3A0%2C%22contact_freq%22%3A%220%22%2C%22contact_freq_type%22%3A%22na%22%2C%22last_session_start_time%22%3A%22na%22%7D%2C%22site_interests%22%3A%7B%22cancer%22%3A%22na%22%2C%22hospital%22%3A%22na%22%2C%22survivor%22%3A%22no%22%2C%22become_patient%22%3A%22no%22%2C%22insurance%22%3A%22no%22%7D%2C%22source%22%3A%22google%22%2C%22source_code%22%3A%22non_branded_natural_search_google%22%2C%22t_pos%22%3A%22na%22%2C%22ua%22%3A%22Mozilla%2F5.0%20(Windows%20NT%2010.0%3B%20Win64%3B%20x64)%20AppleWebKit%2F537.36%20(KHTML%2C%20like%20Gecko)%20Chrome%2F128.0.0.0%20Safari%2F537.36%22%2C%22ga_measurement_id%22%3A%22G-K625FN3PRT%22%2C%22utm_medium%22%3A%22organic%22%2C%22utm_source%22%3A%22google.com%22%2C%22invoca_id%22%3A%22i-65721652-d6ae-4ddd-eafd-97c9c73295db%22%2C%22ga_session_id%22%3A%221727263911%22%2C%22g_cid%22%3A%222072042580.1727263911%22%7D%2C%22config%22%3A%7B%22ce%22%3Atrue%2C%22fv%22%3Afalse%2C%22rn%22%3Afalse%7D%7D',
    'Sec-Cha-Ua': '"Chromium";v="128", "Not;A=Brand";v="24", "Google Chrome";v="128"',
    'Sec-Cha-Ua-Mobile': '?0',
    'Sec-Cha-Ua-Platform': "Windows",
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36'
}

doc_urls = []

for page in range(0, 63):
    url = f'https://www.cityofhope.org/patients/find-a-doctor?page={page}'
    r = requests.get(url, headers=headers)
    #print(r.status_code)
    soup = bs(r.text, 'html.parser')


    docs = soup.find_all('a', class_='field--name-title')
    for i in docs:
        link = i.get('href')
        doc_urls.append(base + link)
    print('Page', page+1, 'done:', len(doc_urls))
    page += 1

print('Total docs: ', len(doc_urls))
#for i in doc_urls: print(i)
# Out:
# Page 1 done: 10
# Page 2 done: 20
# Page 3 done: 30
# Page 4 done: 30
# Page 5 done: 40
# Page 6 done: 50
# Page 7 done: 60
# Page 8 done: 70
# Page 9 done: 80
# Page 10 done: 90
# Page 11 done: 90
# Page 12 done: 100
# Page 13 done: 100
# Page 14 done: 100
# Page 15 done: 100
# https://www.cityofhope.org/shen-li
# https://www.cityofhope.org/wei-li
# https://www.cityofhope.org/farhad-mazdisnian
# https://www.cityofhope.org/kevin-mcdonnell
# https://www.cityofhope.org/heather-mcgee
# https://www.cityofhope.org/eric-mecusker
# https://www.cityofhope.org/matthew-mei
# https://www.cityofhope.org/laleh-melstrom
# https://www.cityofhope.org/kurt-melstrom
# https://www.cityofhope.org/vincent-mendiola
# https://www.cityofhope.org/paul-menzel
# https://www.cityofhope.org/amartej-merla
# https://www.cityofhope.org/jeffrey-metts
# https://www.cityofhope.org/rizvan-mirza
# https://www.cityofhope.org/emmanuel-mitsinikos
# https://www.cityofhope.org/jonathan-moayyad
# https://www.cityofhope.org/badri-modi
# https://www.cityofhope.org/jeremy-montez
# https://www.cityofhope.org/stefanie-mooney
# https://www.cityofhope.org/joanne-mortimer
# https://www.cityofhope.org/reza-mostofi
# https://www.cityofhope.org/pejman-motarjem
# https://www.cityofhope.org/an-nguyen
# https://www.cityofhope.org/danny-nguyen
# https://www.cityofhope.org/andrew-nguyen
# https://www.cityofhope.org/gian-nhan
# https://www.cityofhope.org/aileen-novero
# https://www.cityofhope.org/adeboye-ogunseitan
# https://www.cityofhope.org/karla-olmedo
# https://www.cityofhope.org/salman-otoukesh
# https://www.cityofhope.org/elesyia-outlaw-evans
# https://www.cityofhope.org/sumanta-pal
# https://www.cityofhope.org/aleksandar-sekulic
# https://www.cityofhope.org/george-semeniuk-iii
# https://www.cityofhope.org/stephen-sentovich
# https://www.cityofhope.org/judy-sequeira
# https://www.cityofhope.org/tyler-seto
# https://www.cityofhope.org/nikita-shah
# https://www.cityofhope.org/anand-shah
# https://www.cityofhope.org/karan-shah
# https://www.cityofhope.org/lily-shakibnia
# https://www.cityofhope.org/nitika-sharma
# https://www.cityofhope.org/andrea-ziegler
# https://www.cityofhope.org/michael-zourabian

# %% [markdown]
# # Nghs

# %%
import requests

page = 1
url = f'https://doctors.nghs.com/api/searchservice-v9/nghs/providers?facet=provider.direct_book_capable&facet=provider.accepting_new_patients&facet=provider.specialties.name&facet=provider.telehealth&facet=provider.gender&facet=provider.languages&facet=provider.age_groups_seen&facet=provider.insurance_accepted&facet=provider.provider_type&facet=locations.primary_marketable_location_id&sort=relevance%2Cnetworks%2Cdistance%2Cavailability_density_best&search_alerts=false&shuffle_seed=45f6eccd-dbb5-4af4-ae47-d1c97887bc12&provider_fields=-clinical_keywords&page={page}&context=nghs_pmc&tracking_token=684d14c4-de40-44c8-8004-326ce0ebf243&search_token=43f5d8d3-ac18-4cd7-a599-77b90a838283&user_id=2001ff2c-0b6b-5f44-b162-ac50491ec259&user_token=ca86e4cb-a942-4fc7-bb5c-036e58a089b1&per_page=10'

headers = {
    'Accept': 'application/json, text/plain, */*', 
    'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Accept-Language': 'en-US,en;q=0.9',
    'Cookie': 'visid_incap_2813606=pLYmt7jpSn6cBZ798iSxCstE9mYAAAAAQUIPAAAAAAA89684GNXG2navwSx4whJA; incap_ses_170_2813606=fMAlfaVgjkyEc07FPvZbArVM9mYAAAAArRShP3p7nx5WIa9vTySDmQ==; nlbi_2813606=zw4bBB+GlzxbfA3DucDDzAAAAAAIHsJquGKIFweoLs0FVF2q; consumer_tracking_token=684d14c4-de40-44c8-8004-326ce0ebf243; search_shuffle_token=45f6eccd-dbb5-4af4-ae47-d1c97887bc12; consumer_user_token=ca86e4cb-a942-4fc7-bb5c-036e58a089b1; incap_ses_2107_2813606=0O1PMjjL01vjmUp4e5E9HVNN9mYAAAAAqEHnGyJZcNcC+OSAnj+18Q==; incap_ses_524_2813606=rCSRT0ZiVwDjuTWFbJ9FB7ZP9mYAAAAAWzMGgB4e8lekGBglNMQXfQ==; reese84=3:rqtdOHFjV7q9iGZEYgBSiQ==:...:LbIeJRHdJXOIII4bpntNNON67EeF8t5bAhHwogGY2c0=; nlbi_2813606_2147483392=EH5FTAuqGDOfJk7XucDDzAAAAACZLrzHvg0bgrEEjWBumw8a; utag_main=v_id:0192321e42ce0014bb4f6db6e4050506f006006700978$_sn:1$_se:2$_ss:0$_st:1727420100568$ses_id:1727417696976%3Bexp-session$_pn:2%3Bexp-session$dc_visit:1$dc_event:1%3Bexp-session$dc_region:us-west-2%3Bexp-session',
    'Referer': 'https://doctors.nghs.com/search?sort=relevance%2Cnetworks%2Cdistance%2Cavailability_density_best&search_alerts=false&shuffle_seed=45f6eccd-dbb5-4af4-ae47-d1c97887bc12&provider_fields=-clinical_keywords&page=2',
    'Sec-Cha-Ua': '"Google Chrome";v="129", "Not=A?Brand";v="8", "Chromium";v="129"',
    'Sec-Cha-Ua-Mobile': '?0',
    'Sec-Cha-Ua-Platform': '"Windows"',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36'
}

r = requests.get(url, headers=headers) # type: ignore
print(r.status_code)
# Out:
# 401

# %% [markdown]
# # Advent Health

# %%
import requests
from bs4 import BeautifulSoup as bs

page = 0

url = f'https://www.stcharleshealthcare.org/providers?search=&page={page}'
doc_urls = []
headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Accept-Language': 'en-US,en;q=0.9',
    'Sec-Cha-Ua': '"Google Chrome";v="129", "Not=A?Brand";v="8", "Chromium";v="129"',
    'Sec-Cha-Ua-Mobile': '?0',
    'Sec-Cha-Ua-Platform': '"Windows"',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36'
}
while page <= 15:
    r = requests.get(url, headers=headers)
    soup = bs(r.content, 'html.parser')

    docs = soup.find_all('h3')
    for doc in docs:
        doc_link = doc.find_all('a', href=True)
        if doc_link:
            doc_urls.append(doc_link[0]['href'])
    print(f"Page {page} done: ", len(doc_urls))
    page += 1
print(len(doc_urls))
for i in doc_urls: print(i)
# Out:
# Page 0 done:  10
# Page 1 done:  20
# Page 2 done:  30
# Page 3 done:  40
# Page 4 done:  50
# Page 5 done:  60
# Page 6 done:  70
# Page 7 done:  80
# Page 8 done:  90
# Page 9 done:  100
# Page 10 done:  110
# Page 11 done:  120
# Page 12 done:  130
# Page 13 done:  140
# Page 14 done:  150
# Page 15 done:  160
# 160
# https://www.stcharleshealthcare.org/providers/pamela-seidel-lcsw
# https://www.stcharleshealthcare.org/providers/meghan-gilroy-md
# https://www.stcharleshealthcare.org/providers/victor-duong-do
# https://www.stcharleshealthcare.org/providers/patrick-cassiday-md-phd
# https://www.stcharleshealthcare.org/providers/kelsey-wickham-fnp
# https://www.stcharleshealthcare.org/providers/walter-griffin-do
# https://www.stcharleshealthcare.org/providers/anna-esko-lcsw
# https://www.stcharleshealthcare.org/providers/shanna-humphrey-ot
# https://www.stcharleshealthcare.org/providers/ashley-lane-pa
# https://www.stcharleshealthcare.org/providers/matthew-giordanengo-do
# https://www.stcharleshealthcare.org/providers/pamela-seidel-lcsw
# https://www.stcharleshealthcare.org/providers/meghan-gilroy-md
# https://www.stcharleshealthcare.org/providers/victor-duong-do
# https://www.stcharleshealthcare.org/providers/patrick-cassiday-md-phd
# https://www.stcharleshealthcare.org/providers/kelsey-wickham-fnp
# https://www.stcharleshealthcare.org/providers/walter-griffin-do
# https://www.stcharleshealthcare.org/providers/anna-esko-lcsw
# https://www.stcharleshealthcare.org/providers/shanna-humphrey-ot
# https://www.stcharleshealthcare.org/providers/ashley-lane-pa
# https://www.stcharleshealthcare.org/providers/matthew-giordanengo-do
# https://www.stcharleshealthcare.org/providers/pamela-seidel-lcsw
# https://www.stcharleshealthcare.org/providers/meghan-gilroy-md
# https://www.stcharleshealthcare.org/providers/victor-duong-do
# https://www.stcharleshealthcare.org/providers/patrick-cassiday-md-phd
# https://www.stcharleshealthcare.org/providers/kelsey-wickham-fnp
# https://www.stcharleshealthcare.org/providers/walter-griffin-do
# https://www.stcharleshealthcare.org/providers/anna-esko-lcsw
# https://www.stcharleshealthcare.org/providers/shanna-humphrey-ot
# https://www.stcharleshealthcare.org/providers/ashley-lane-pa
# https://www.stcharleshealthcare.org/providers/matthew-giordanengo-do
# https://www.stcharleshealthcare.org/providers/pamela-seidel-lcsw
# https://www.stcharleshealthcare.org/providers/meghan-gilroy-md
# https://www.stcharleshealthcare.org/providers/victor-duong-do
# https://www.stcharleshealthcare.org/providers/patrick-cassiday-md-phd
# https://www.stcharleshealthcare.org/providers/kelsey-wickham-fnp
# https://www.stcharleshealthcare.org/providers/walter-griffin-do
# https://www.stcharleshealthcare.org/providers/anna-esko-lcsw
# https://www.stcharleshealthcare.org/providers/shanna-humphrey-ot
# https://www.stcharleshealthcare.org/providers/ashley-lane-pa
# https://www.stcharleshealthcare.org/providers/matthew-giordanengo-do
# https://www.stcharleshealthcare.org/providers/pamela-seidel-lcsw
# https://www.stcharleshealthcare.org/providers/meghan-gilroy-md
# https://www.stcharleshealthcare.org/providers/victor-duong-do
# https://www.stcharleshealthcare.org/providers/patrick-cassiday-md-phd
# https://www.stcharleshealthcare.org/providers/kelsey-wickham-fnp
# https://www.stcharleshealthcare.org/providers/walter-griffin-do
# https://www.stcharleshealthcare.org/providers/anna-esko-lcsw
# https://www.stcharleshealthcare.org/providers/shanna-humphrey-ot
# https://www.stcharleshealthcare.org/providers/ashley-lane-pa
# https://www.stcharleshealthcare.org/providers/matthew-giordanengo-do
# https://www.stcharleshealthcare.org/providers/pamela-seidel-lcsw
# https://www.stcharleshealthcare.org/providers/meghan-gilroy-md
# https://www.stcharleshealthcare.org/providers/victor-duong-do
# https://www.stcharleshealthcare.org/providers/patrick-cassiday-md-phd
# https://www.stcharleshealthcare.org/providers/kelsey-wickham-fnp
# https://www.stcharleshealthcare.org/providers/walter-griffin-do
# https://www.stcharleshealthcare.org/providers/anna-esko-lcsw
# https://www.stcharleshealthcare.org/providers/shanna-humphrey-ot
# https://www.stcharleshealthcare.org/providers/ashley-lane-pa
# https://www.stcharleshealthcare.org/providers/matthew-giordanengo-do
# https://www.stcharleshealthcare.org/providers/pamela-seidel-lcsw
# https://www.stcharleshealthcare.org/providers/meghan-gilroy-md
# https://www.stcharleshealthcare.org/providers/victor-duong-do
# https://www.stcharleshealthcare.org/providers/patrick-cassiday-md-phd
# https://www.stcharleshealthcare.org/providers/kelsey-wickham-fnp
# https://www.stcharleshealthcare.org/providers/walter-griffin-do
# https://www.stcharleshealthcare.org/providers/anna-esko-lcsw
# https://www.stcharleshealthcare.org/providers/shanna-humphrey-ot
# https://www.stcharleshealthcare.org/providers/ashley-lane-pa
# https://www.stcharleshealthcare.org/providers/matthew-giordanengo-do
# https://www.stcharleshealthcare.org/providers/pamela-seidel-lcsw
# https://www.stcharleshealthcare.org/providers/meghan-gilroy-md
# https://www.stcharleshealthcare.org/providers/victor-duong-do
# https://www.stcharleshealthcare.org/providers/patrick-cassiday-md-phd
# https://www.stcharleshealthcare.org/providers/kelsey-wickham-fnp
# https://www.stcharleshealthcare.org/providers/walter-griffin-do
# https://www.stcharleshealthcare.org/providers/anna-esko-lcsw
# https://www.stcharleshealthcare.org/providers/shanna-humphrey-ot
# https://www.stcharleshealthcare.org/providers/ashley-lane-pa
# https://www.stcharleshealthcare.org/providers/matthew-giordanengo-do
# https://www.stcharleshealthcare.org/providers/pamela-seidel-lcsw
# https://www.stcharleshealthcare.org/providers/meghan-gilroy-md
# https://www.stcharleshealthcare.org/providers/victor-duong-do
# https://www.stcharleshealthcare.org/providers/patrick-cassiday-md-phd
# https://www.stcharleshealthcare.org/providers/kelsey-wickham-fnp
# https://www.stcharleshealthcare.org/providers/walter-griffin-do
# https://www.stcharleshealthcare.org/providers/anna-esko-lcsw
# https://www.stcharleshealthcare.org/providers/shanna-humphrey-ot
# https://www.stcharleshealthcare.org/providers/ashley-lane-pa
# https://www.stcharleshealthcare.org/providers/matthew-giordanengo-do
# https://www.stcharleshealthcare.org/providers/pamela-seidel-lcsw
# https://www.stcharleshealthcare.org/providers/meghan-gilroy-md
# https://www.stcharleshealthcare.org/providers/victor-duong-do
# https://www.stcharleshealthcare.org/providers/patrick-cassiday-md-phd
# https://www.stcharleshealthcare.org/providers/kelsey-wickham-fnp
# https://www.stcharleshealthcare.org/providers/walter-griffin-do
# https://www.stcharleshealthcare.org/providers/anna-esko-lcsw
# https://www.stcharleshealthcare.org/providers/shanna-humphrey-ot
# https://www.stcharleshealthcare.org/providers/ashley-lane-pa
# https://www.stcharleshealthcare.org/providers/matthew-giordanengo-do
# https://www.stcharleshealthcare.org/providers/pamela-seidel-lcsw
# https://www.stcharleshealthcare.org/providers/meghan-gilroy-md
# https://www.stcharleshealthcare.org/providers/victor-duong-do
# https://www.stcharleshealthcare.org/providers/patrick-cassiday-md-phd
# https://www.stcharleshealthcare.org/providers/kelsey-wickham-fnp
# https://www.stcharleshealthcare.org/providers/walter-griffin-do
# https://www.stcharleshealthcare.org/providers/anna-esko-lcsw
# https://www.stcharleshealthcare.org/providers/shanna-humphrey-ot
# https://www.stcharleshealthcare.org/providers/ashley-lane-pa
# https://www.stcharleshealthcare.org/providers/matthew-giordanengo-do
# https://www.stcharleshealthcare.org/providers/pamela-seidel-lcsw
# https://www.stcharleshealthcare.org/providers/meghan-gilroy-md
# https://www.stcharleshealthcare.org/providers/victor-duong-do
# https://www.stcharleshealthcare.org/providers/patrick-cassiday-md-phd
# https://www.stcharleshealthcare.org/providers/kelsey-wickham-fnp
# https://www.stcharleshealthcare.org/providers/walter-griffin-do
# https://www.stcharleshealthcare.org/providers/anna-esko-lcsw
# https://www.stcharleshealthcare.org/providers/shanna-humphrey-ot
# https://www.stcharleshealthcare.org/providers/ashley-lane-pa
# https://www.stcharleshealthcare.org/providers/matthew-giordanengo-do
# https://www.stcharleshealthcare.org/providers/pamela-seidel-lcsw
# https://www.stcharleshealthcare.org/providers/meghan-gilroy-md
# https://www.stcharleshealthcare.org/providers/victor-duong-do
# https://www.stcharleshealthcare.org/providers/patrick-cassiday-md-phd
# https://www.stcharleshealthcare.org/providers/kelsey-wickham-fnp
# https://www.stcharleshealthcare.org/providers/walter-griffin-do
# https://www.stcharleshealthcare.org/providers/anna-esko-lcsw
# https://www.stcharleshealthcare.org/providers/shanna-humphrey-ot
# https://www.stcharleshealthcare.org/providers/ashley-lane-pa
# https://www.stcharleshealthcare.org/providers/matthew-giordanengo-do
# https://www.stcharleshealthcare.org/providers/pamela-seidel-lcsw
# https://www.stcharleshealthcare.org/providers/meghan-gilroy-md
# https://www.stcharleshealthcare.org/providers/victor-duong-do
# https://www.stcharleshealthcare.org/providers/patrick-cassiday-md-phd
# https://www.stcharleshealthcare.org/providers/kelsey-wickham-fnp
# https://www.stcharleshealthcare.org/providers/walter-griffin-do
# https://www.stcharleshealthcare.org/providers/anna-esko-lcsw
# https://www.stcharleshealthcare.org/providers/shanna-humphrey-ot
# https://www.stcharleshealthcare.org/providers/ashley-lane-pa
# https://www.stcharleshealthcare.org/providers/matthew-giordanengo-do
# https://www.stcharleshealthcare.org/providers/pamela-seidel-lcsw
# https://www.stcharleshealthcare.org/providers/meghan-gilroy-md
# https://www.stcharleshealthcare.org/providers/victor-duong-do
# https://www.stcharleshealthcare.org/providers/patrick-cassiday-md-phd
# https://www.stcharleshealthcare.org/providers/kelsey-wickham-fnp
# https://www.stcharleshealthcare.org/providers/walter-griffin-do
# https://www.stcharleshealthcare.org/providers/anna-esko-lcsw
# https://www.stcharleshealthcare.org/providers/shanna-humphrey-ot
# https://www.stcharleshealthcare.org/providers/ashley-lane-pa
# https://www.stcharleshealthcare.org/providers/matthew-giordanengo-do
# https://www.stcharleshealthcare.org/providers/pamela-seidel-lcsw
# https://www.stcharleshealthcare.org/providers/meghan-gilroy-md
# https://www.stcharleshealthcare.org/providers/victor-duong-do
# https://www.stcharleshealthcare.org/providers/patrick-cassiday-md-phd
# https://www.stcharleshealthcare.org/providers/kelsey-wickham-fnp
# https://www.stcharleshealthcare.org/providers/walter-griffin-do
# https://www.stcharleshealthcare.org/providers/anna-esko-lcsw
# https://www.stcharleshealthcare.org/providers/shanna-humphrey-ot
# https://www.stcharleshealthcare.org/providers/ashley-lane-pa
# https://www.stcharleshealthcare.org/providers/matthew-giordanengo-do
